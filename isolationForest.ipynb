# %%
import pandas as pd
from sklearn.ensemble import IsolationForest, RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# Load and preprocess the data
df = pd.read_csv('data.csv')
df['amount_ratio'] = df['amount'] / df['oldbalanceOrg'].replace(0, 1)
df['balance_diff'] = df['newbalanceDest'] - df['oldbalanceDest']
df['origin_balance_change'] = df['oldbalanceOrg'] - df['newbalanceOrig']

# %%
# Features for Isolation Forest
X = df[['amount', 'amount_ratio', 'balance_diff', 'origin_balance_change']]

# %%
# Apply Isolation Forest
iso_forest = IsolationForest(n_estimators=100, contamination=0.01, random_state=42, n_jobs=-1)
df['anomaly'] = iso_forest.fit_predict(X)

# %%
# Convert anomaly labels to match your labeling convention
# -1 for outliers (anomalies), 1 for inliers (normal data)
df['label'] = df['isFraud']
df.loc[df['anomaly'] == -1, 'label'] = 2  # Mark anomalies as suspicious

# %%
# Prepare data for supervised learning
X_train, X_test, y_train, y_test = train_test_split(X, df['label'], test_size=0.3, random_state=42)

# %%
# Train a classifier on labeled data
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluate the model
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1888203
#            1       1.00      0.99      1.00      1921
#            2       1.00      1.00      1.00     18662
#
#     accuracy                           1.00   1908786
#    macro avg       1.00      1.00      1.00   1908786
# weighted avg       1.00      1.00      1.00   1908786

# %%
# Count the number of transactions in each category
category_counts = df['label'].value_counts()

# Display the counts
print("Number of transactions in each category:")
print(f"Non-Fraudulent (0): {category_counts.get(0, 0)}")
print(f"Fraudulent (1): {category_counts.get(1, 0)}")
print(f"Suspicious (2): {category_counts.get(2, 0)}")
# Out:
# Number of transactions in each category:
# Non-Fraudulent (0): 6293520
# Fraudulent (1): 6412
# Suspicious (2): 62688

# %%
# Alert Program Function
def alert_system(transaction):
    pred = model.predict(transaction)
    if pred == 1:
        return "ALERT: Fraudulent Transaction!"
    elif pred == 2:
        return "ALERT: Suspicious Transaction!"
    else:
        return "Transaction is Normal."

# %%
sample_transaction = pd.DataFrame({
    'amount': [50000],  # Set an example amount
    'amount_ratio': [0.8],  # Set example ratio
    'balance_diff': [30000],  # Set example balance difference
    'origin_balance_change': [-20000]  # Set example origin balance change
})
alert = alert_system(sample_transaction)
print(alert)
# Out:
# Transaction is Normal.

# %%
import numpy as np

index =   420
transaction = X_test.iloc[[index]]  

# Test the alert_system function
alert = alert_system(transaction)
print(f"Transaction {index}: {alert}")
# Out:
# Transaction 420: ALERT: Fraudulent Transaction!

# %%
import numpy as np

index =  3
transaction = X_test.iloc[[index]]  

# Test the alert_system function
alert = alert_system(transaction)
print(f"Transaction {index}: {alert}")
# Out:
# Transaction 3: ALERT: Suspicious Transaction!

# %%
import pandas as pd
import numpy as np

for index in range(len(X_test)):
 
    transaction = X_test.iloc[[index]]  

    
    alert = alert_system(transaction)
    print(f"Transaction {index}: {alert}")
# Out:
# Transaction 0: Transaction is Normal.
# Transaction 1: Transaction is Normal.
# Transaction 2: Transaction is Normal.
# Transaction 3: ALERT: Suspicious Transaction!
# Transaction 4: Transaction is Normal.
# Transaction 5: Transaction is Normal.
# Transaction 6: Transaction is Normal.
# Transaction 7: Transaction is Normal.
# Transaction 8: Transaction is Normal.
# Transaction 9: Transaction is Normal.
# Transaction 10: Transaction is Normal.
# Transaction 11: Transaction is Normal.
# Transaction 12: Transaction is Normal.
# Transaction 13: Transaction is Normal.
# Transaction 14: Transaction is Normal.
# Transaction 15: Transaction is Normal.
# Transaction 16: Transaction is Normal.
# Transaction 17: Transaction is Normal.
# Transaction 18: Transaction is Normal.
# Transaction 19: Transaction is Normal.
# Transaction 20: Transaction is Normal.
# Transaction 21: Transaction is Normal.
# Transaction 22: Transaction is Normal.
# Transaction 23: Transaction is Normal.
# Transaction 24: Transaction is Normal.
# Transaction 25: Transaction is Normal.
# Transaction 26: Transaction is Normal.
# Transaction 27: Transaction is Normal.
# Transaction 28: Transaction is Normal.
# Transaction 29: Transaction is Normal.
# Transaction 30: Transaction is Normal.
# Transaction 31: Transaction is Normal.
# Transaction 32: Transaction is Normal.
# Transaction 33: Transaction is Normal.
# Transaction 34: Transaction is Normal.
# Transaction 35: Transaction is Normal.
# Transaction 36: Transaction is Normal.
# Transaction 37: Transaction is Normal.
# Transaction 38: Transaction is Normal.
# Transaction 39: Transaction is Normal.
# Transaction 40: Transaction is Normal.
# Transaction 41: Transaction is Normal.
# Transaction 42: Transaction is Normal.
# Transaction 43: Transaction is Normal.
# Transaction 44: Transaction is Normal.
# Transaction 45: Transaction is Normal.
# Transaction 46: Transaction is Normal.
# Transaction 47: Transaction is Normal.
# Transaction 48: Transaction is Normal.
# Transaction 49: Transaction is Normal.
# Transaction 50: Transaction is Normal.
# Transaction 51: Transaction is Normal.
# Transaction 52: Transaction is Normal.
# Transaction 53: Transaction is Normal.
# Transaction 54: Transaction is Normal.
# Transaction 55: Transaction is Normal.
# Transaction 56: Transaction is Normal.
# Transaction 57: Transaction is Normal.
# Transaction 58: Transaction is Normal.
# Transaction 59: Transaction is Normal.
# Transaction 60: Transaction is Normal.
# Transaction 61: Transaction is Normal.
# Transaction 62: Transaction is Normal.
# Transaction 63: Transaction is Normal.
# Transaction 64: Transaction is Normal.
# Transaction 65: Transaction is Normal.
# Transaction 66: Transaction is Normal.
# Transaction 67: Transaction is Normal.
# Transaction 68: Transaction is Normal.
# Transaction 69: Transaction is Normal.
# Transaction 70: Transaction is Normal.
# Transaction 71: Transaction is Normal.
# Transaction 72: Transaction is Normal.
# Transaction 73: Transaction is Normal.
# Transaction 74: Transaction is Normal.
# Transaction 75: Transaction is Normal.
# Transaction 76: Transaction is Normal.
# Transaction 77: Transaction is Normal.
# Transaction 78: Transaction is Normal.
# Transaction 79: Transaction is Normal.
# Transaction 80: Transaction is Normal.
# Transaction 81: Transaction is Normal.
# Transaction 82: Transaction is Normal.
# Transaction 83: Transaction is Normal.
# Transaction 84: Transaction is Normal.
# Transaction 85: Transaction is Normal.
# Transaction 86: Transaction is Normal.
# Transaction 87: Transaction is Normal.
# Transaction 88: Transaction is Normal.
# Transaction 89: Transaction is Normal.
# Transaction 90: Transaction is Normal.
# Transaction 91: Transaction is Normal.
# Transaction 92: Transaction is Normal.
# Transaction 93: Transaction is Normal.
# Transaction 94: Transaction is Normal.
# Transaction 95: Transaction is Normal.
# Transaction 96: Transaction is Normal.
# Transaction 97: Transaction is Normal.
# Transaction 98: Transaction is Normal.
# Transaction 99: Transaction is Normal.
# Transaction 100: Transaction is Normal.
# Transaction 101: Transaction is Normal.
# Transaction 102: Transaction is Normal.
# Transaction 103: Transaction is Normal.
# Transaction 104: Transaction is Normal.
# Transaction 105: Transaction is Normal.
# Transaction 106: Transaction is Normal.
# Transaction 107: Transaction is Normal.
# Transaction 108: Transaction is Normal.
# Transaction 109: Transaction is Normal.
# Transaction 110: Transaction is Normal.
# Transaction 111: Transaction is Normal.
# Transaction 112: Transaction is Normal.
# Transaction 113: Transaction is Normal.
# Transaction 114: Transaction is Normal.
# Transaction 115: Transaction is Normal.
# Transaction 116: Transaction is Normal.
# Transaction 117: Transaction is Normal.
# Transaction 118: Transaction is Normal.
# Transaction 119: Transaction is Normal.
# Transaction 120: Transaction is Normal.
# Transaction 121: Transaction is Normal.
# Transaction 122: Transaction is Normal.
# Transaction 123: Transaction is Normal.
# Transaction 124: Transaction is Normal.
# Transaction 125: Transaction is Normal.
# Transaction 126: Transaction is Normal.
# Transaction 127: Transaction is Normal.
# Transaction 128: Transaction is Normal.
# Transaction 129: Transaction is Normal.
# Transaction 130: Transaction is Normal.
# Transaction 131: Transaction is Normal.
# Transaction 132: Transaction is Normal.
# Transaction 133: Transaction is Normal.
# Transaction 134: Transaction is Normal.
# Transaction 135: Transaction is Normal.
# Transaction 136: Transaction is Normal.
# Transaction 137: Transaction is Normal.
# Transaction 138: Transaction is Normal.
# Transaction 139: Transaction is Normal.
# Transaction 140: Transaction is Normal.
# Transaction 141: Transaction is Normal.
# Transaction 142: Transaction is Normal.
# Transaction 143: Transaction is Normal.
# Transaction 144: Transaction is Normal.
# Transaction 145: Transaction is Normal.
# Transaction 146: Transaction is Normal.
# Transaction 147: Transaction is Normal.
# Transaction 148: Transaction is Normal.
# Transaction 149: Transaction is Normal.
# Transaction 150: Transaction is Normal.
# Transaction 151: Transaction is Normal.
# Transaction 152: Transaction is Normal.
# Transaction 153: Transaction is Normal.
# Transaction 154: Transaction is Normal.
# Transaction 155: Transaction is Normal.
# Transaction 156: Transaction is Normal.
# Transaction 157: Transaction is Normal.
# Transaction 158: Transaction is Normal.
# Transaction 159: Transaction is Normal.
# Transaction 160: Transaction is Normal.
# Transaction 161: Transaction is Normal.
# Transaction 162: Transaction is Normal.
# Transaction 163: Transaction is Normal.
# Transaction 164: Transaction is Normal.
# Transaction 165: Transaction is Normal.
# Transaction 166: Transaction is Normal.
# Transaction 167: Transaction is Normal.
# Transaction 168: Transaction is Normal.
# Transaction 169: Transaction is Normal.
# Transaction 170: Transaction is Normal.
# Transaction 171: Transaction is Normal.
# Transaction 172: Transaction is Normal.
# Transaction 173: Transaction is Normal.
# Transaction 174: Transaction is Normal.
# Transaction 175: Transaction is Normal.
# Transaction 176: Transaction is Normal.
# Transaction 177: Transaction is Normal.
# Transaction 178: Transaction is Normal.
# Transaction 179: Transaction is Normal.
# Transaction 180: Transaction is Normal.
# Transaction 181: Transaction is Normal.
# Transaction 182: Transaction is Normal.
# Transaction 183: Transaction is Normal.
# Transaction 184: Transaction is Normal.
# Transaction 185: Transaction is Normal.
# Transaction 186: Transaction is Normal.
# Transaction 187: Transaction is Normal.
# Transaction 188: Transaction is Normal.
# Transaction 189: Transaction is Normal.
# Transaction 190: Transaction is Normal.
# Transaction 191: Transaction is Normal.
# Transaction 192: Transaction is Normal.
# Transaction 193: Transaction is Normal.
# Transaction 194: Transaction is Normal.
# Transaction 195: Transaction is Normal.
# Transaction 196: Transaction is Normal.
# Transaction 197: Transaction is Normal.
# Transaction 198: Transaction is Normal.
# Transaction 199: Transaction is Normal.
# Transaction 200: Transaction is Normal.
# Transaction 201: Transaction is Normal.
# Transaction 202: Transaction is Normal.
# Transaction 203: Transaction is Normal.
# Transaction 204: Transaction is Normal.
# Transaction 205: Transaction is Normal.
# Transaction 206: Transaction is Normal.
# Transaction 207: Transaction is Normal.
# Transaction 208: Transaction is Normal.
# Transaction 209: Transaction is Normal.
# Transaction 210: Transaction is Normal.
# Transaction 211: Transaction is Normal.
# Transaction 212: Transaction is Normal.
# Transaction 213: Transaction is Normal.
# Transaction 214: Transaction is Normal.
# Transaction 215: Transaction is Normal.
# Transaction 216: Transaction is Normal.
# Transaction 217: Transaction is Normal.
# Transaction 218: Transaction is Normal.
# Transaction 219: Transaction is Normal.
# Transaction 220: Transaction is Normal.
# Transaction 221: Transaction is Normal.
# Transaction 222: Transaction is Normal.
# Transaction 223: Transaction is Normal.
# Transaction 224: Transaction is Normal.
# Transaction 225: Transaction is Normal.
# Transaction 226: Transaction is Normal.
# Transaction 227: Transaction is Normal.
# Transaction 228: Transaction is Normal.
# Transaction 229: Transaction is Normal.
# Transaction 230: Transaction is Normal.
# Transaction 231: Transaction is Normal.
# Transaction 232: Transaction is Normal.
# Transaction 233: Transaction is Normal.
# Transaction 234: Transaction is Normal.
# Transaction 235: Transaction is Normal.
# Transaction 236: Transaction is Normal.
# Transaction 237: Transaction is Normal.
# Transaction 238: Transaction is Normal.
# Transaction 239: Transaction is Normal.
# Transaction 240: Transaction is Normal.
# Transaction 241: Transaction is Normal.
# Transaction 242: Transaction is Normal.
# Transaction 243: Transaction is Normal.
# Transaction 244: Transaction is Normal.
# Transaction 245: Transaction is Normal.
# Transaction 246: Transaction is Normal.
# Transaction 247: Transaction is Normal.
# Transaction 248: Transaction is Normal.
# Transaction 249: Transaction is Normal.
# Transaction 250: Transaction is Normal.
# Transaction 251: Transaction is Normal.
# Transaction 252: Transaction is Normal.
# Transaction 253: Transaction is Normal.
# Transaction 254: Transaction is Normal.
# Transaction 255: Transaction is Normal.
# Transaction 256: Transaction is Normal.
# Transaction 257: Transaction is Normal.
# Transaction 258: Transaction is Normal.
# Transaction 259: Transaction is Normal.
# Transaction 260: Transaction is Normal.
# Transaction 261: Transaction is Normal.
# Transaction 262: Transaction is Normal.
# Transaction 263: Transaction is Normal.
# Transaction 264: Transaction is Normal.
# Transaction 265: Transaction is Normal.
# Transaction 266: Transaction is Normal.
# Transaction 267: Transaction is Normal.
# Transaction 268: Transaction is Normal.
# Transaction 269: Transaction is Normal.
# Transaction 270: Transaction is Normal.
# Transaction 271: Transaction is Normal.
# Transaction 272: Transaction is Normal.
# Transaction 273: Transaction is Normal.
# Transaction 274: Transaction is Normal.
# Transaction 275: Transaction is Normal.
# Transaction 276: Transaction is Normal.
# Transaction 277: Transaction is Normal.
# Transaction 278: Transaction is Normal.
# Transaction 279: Transaction is Normal.
# Transaction 280: Transaction is Normal.
# Transaction 281: Transaction is Normal.
# Transaction 282: Transaction is Normal.
# Transaction 283: ALERT: Fraudulent Transaction!
# Transaction 284: Transaction is Normal.
# Transaction 285: Transaction is Normal.
# Transaction 286: Transaction is Normal.
# Transaction 287: Transaction is Normal.
# Transaction 288: Transaction is Normal.
# Transaction 289: Transaction is Normal.
# Transaction 290: Transaction is Normal.
# Transaction 291: Transaction is Normal.
# Transaction 292: Transaction is Normal.
# Transaction 293: Transaction is Normal.
# Transaction 294: Transaction is Normal.
# Transaction 295: Transaction is Normal.
# Transaction 296: Transaction is Normal.
# Transaction 297: Transaction is Normal.
# Transaction 298: Transaction is Normal.
# Transaction 299: Transaction is Normal.
# Transaction 300: Transaction is Normal.
# Transaction 301: Transaction is Normal.
# Transaction 302: Transaction is Normal.
# Transaction 303: Transaction is Normal.
# Transaction 304: Transaction is Normal.
# Transaction 305: Transaction is Normal.
# Transaction 306: Transaction is Normal.
# Transaction 307: Transaction is Normal.
# Transaction 308: Transaction is Normal.
# Transaction 309: Transaction is Normal.
# Transaction 310: Transaction is Normal.
# Transaction 311: Transaction is Normal.
# Transaction 312: Transaction is Normal.
# Transaction 313: Transaction is Normal.
# Transaction 314: Transaction is Normal.
# Transaction 315: Transaction is Normal.
# Transaction 316: Transaction is Normal.
# Transaction 317: Transaction is Normal.
# Transaction 318: Transaction is Normal.
# Transaction 319: Transaction is Normal.
# Transaction 320: Transaction is Normal.
# Transaction 321: Transaction is Normal.
# Transaction 322: Transaction is Normal.
# Transaction 323: Transaction is Normal.
# Transaction 324: Transaction is Normal.
# Transaction 325: Transaction is Normal.
# Transaction 326: Transaction is Normal.
# Transaction 327: Transaction is Normal.
# Transaction 328: Transaction is Normal.
# Transaction 329: Transaction is Normal.
# Transaction 330: Transaction is Normal.
# Transaction 331: ALERT: Suspicious Transaction!
# Transaction 332: Transaction is Normal.
# Transaction 333: Transaction is Normal.
# Transaction 334: Transaction is Normal.
# Transaction 335: Transaction is Normal.
# Transaction 336: Transaction is Normal.
# Transaction 337: Transaction is Normal.
# Transaction 338: Transaction is Normal.
# Transaction 339: Transaction is Normal.
# Transaction 340: Transaction is Normal.
# Transaction 341: Transaction is Normal.
# Transaction 342: Transaction is Normal.
# Transaction 343: Transaction is Normal.
# Transaction 344: Transaction is Normal.
# Transaction 345: Transaction is Normal.
# Transaction 346: Transaction is Normal.
# Transaction 347: Transaction is Normal.
# Transaction 348: Transaction is Normal.
# Transaction 349: Transaction is Normal.
# Transaction 350: Transaction is Normal.
# Transaction 351: Transaction is Normal.
# Transaction 352: Transaction is Normal.
# Transaction 353: Transaction is Normal.
# Transaction 354: Transaction is Normal.
# Transaction 355: Transaction is Normal.
# Transaction 356: Transaction is Normal.
# Transaction 357: Transaction is Normal.
# Transaction 358: Transaction is Normal.
# Transaction 359: Transaction is Normal.
# Transaction 360: Transaction is Normal.
# Transaction 361: Transaction is Normal.
# Transaction 362: Transaction is Normal.
# Transaction 363: Transaction is Normal.
# Transaction 364: Transaction is Normal.
# Transaction 365: Transaction is Normal.
# Transaction 366: Transaction is Normal.
# Transaction 367: Transaction is Normal.
# Transaction 368: Transaction is Normal.
# Transaction 369: Transaction is Normal.
# Transaction 370: Transaction is Normal.
# Transaction 371: Transaction is Normal.
# Transaction 372: Transaction is Normal.
# Transaction 373: Transaction is Normal.
# Transaction 374: Transaction is Normal.
# Transaction 375: Transaction is Normal.
# Transaction 376: Transaction is Normal.
# Transaction 377: Transaction is Normal.
# Transaction 378: Transaction is Normal.
# Transaction 379: Transaction is Normal.
# Transaction 380: Transaction is Normal.
# Transaction 381: Transaction is Normal.
# Transaction 382: Transaction is Normal.
# Transaction 383: Transaction is Normal.
# Transaction 384: Transaction is Normal.
# Transaction 385: Transaction is Normal.
# Transaction 386: Transaction is Normal.
# Transaction 387: Transaction is Normal.
# Transaction 388: Transaction is Normal.
# Transaction 389: Transaction is Normal.
# Transaction 390: Transaction is Normal.
# Transaction 391: Transaction is Normal.
# Transaction 392: Transaction is Normal.
# Transaction 393: Transaction is Normal.
# Transaction 394: Transaction is Normal.
# Transaction 395: Transaction is Normal.
# Transaction 396: Transaction is Normal.
# Transaction 397: Transaction is Normal.
# Transaction 398: Transaction is Normal.
# Transaction 399: Transaction is Normal.
# Transaction 400: Transaction is Normal.
# Transaction 401: Transaction is Normal.
# Transaction 402: Transaction is Normal.
# Transaction 403: Transaction is Normal.
# Transaction 404: Transaction is Normal.
# Transaction 405: Transaction is Normal.
# Transaction 406: Transaction is Normal.
# Transaction 407: Transaction is Normal.
# Transaction 408: Transaction is Normal.
# Transaction 409: Transaction is Normal.
# Transaction 410: Transaction is Normal.
# Transaction 411: Transaction is Normal.
# Transaction 412: Transaction is Normal.
# Transaction 413: Transaction is Normal.
# Transaction 414: Transaction is Normal.
# Transaction 415: Transaction is Normal.
# Transaction 416: Transaction is Normal.
# Transaction 417: Transaction is Normal.
# Transaction 418: Transaction is Normal.
# Transaction 419: Transaction is Normal.
# Transaction 420: ALERT: Fraudulent Transaction!
# Transaction 421: Transaction is Normal.
# Transaction 422: Transaction is Normal.
# Transaction 423: Transaction is Normal.
# Transaction 424: Transaction is Normal.
# Transaction 425: Transaction is Normal.
# Transaction 426: Transaction is Normal.
# Transaction 427: Transaction is Normal.
# Transaction 428: Transaction is Normal.
# Transaction 429: Transaction is Normal.
# Transaction 430: Transaction is Normal.
# Transaction 431: Transaction is Normal.
# Transaction 432: Transaction is Normal.
# Transaction 433: Transaction is Normal.
# Transaction 434: Transaction is Normal.
# Transaction 435: Transaction is Normal.
# Transaction 436: Transaction is Normal.
# Transaction 437: Transaction is Normal.
# Transaction 438: Transaction is Normal.
# Transaction 439: Transaction is Normal.
# Transaction 440: Transaction is Normal.
# Transaction 441: Transaction is Normal.
# Transaction 442: Transaction is Normal.
# Transaction 443: Transaction is Normal.
# Transaction 444: Transaction is Normal.
# Transaction 445: Transaction is Normal.
# Transaction 446: Transaction is Normal.
# Transaction 447: Transaction is Normal.
# Transaction 448: Transaction is Normal.
# Transaction 449: Transaction is Normal.
# Transaction 450: Transaction is Normal.
# Transaction 451: Transaction is Normal.
# Transaction 452: Transaction is Normal.
# Transaction 453: Transaction is Normal.
# Transaction 454: Transaction is Normal.
# Transaction 455: Transaction is Normal.
# Transaction 456: Transaction is Normal.
# Transaction 457: Transaction is Normal.
# Transaction 458: Transaction is Normal.
# Transaction 459: Transaction is Normal.
# Transaction 460: Transaction is Normal.
# Transaction 461: Transaction is Normal.
# Transaction 462: Transaction is Normal.
# Transaction 463: Transaction is Normal.
# Transaction 464: Transaction is Normal.
# Transaction 465: Transaction is Normal.
# Transaction 466: Transaction is Normal.
# Transaction 467: Transaction is Normal.
# Transaction 468: Transaction is Normal.
# Transaction 469: Transaction is Normal.
# Transaction 470: Transaction is Normal.
# Transaction 471: Transaction is Normal.
# Transaction 472: Transaction is Normal.
# Transaction 473: Transaction is Normal.
# Transaction 474: Transaction is Normal.
# Transaction 475: Transaction is Normal.
# Transaction 476: Transaction is Normal.
# Transaction 477: Transaction is Normal.
# Transaction 478: Transaction is Normal.
# Transaction 479: Transaction is Normal.
# Transaction 480: Transaction is Normal.
# Transaction 481: Transaction is Normal.
# Transaction 482: Transaction is Normal.
# Transaction 483: Transaction is Normal.
# Transaction 484: Transaction is Normal.
# Transaction 485: Transaction is Normal.
# Transaction 486: Transaction is Normal.
# Transaction 487: Transaction is Normal.
# Transaction 488: Transaction is Normal.
# Transaction 489: Transaction is Normal.
# Transaction 490: Transaction is Normal.
# Transaction 491: Transaction is Normal.
# Transaction 492: Transaction is Normal.
# Transaction 493: Transaction is Normal.
# Transaction 494: Transaction is Normal.
# Transaction 495: Transaction is Normal.
# Transaction 496: Transaction is Normal.
# Transaction 497: Transaction is Normal.
# Transaction 498: Transaction is Normal.
# Transaction 499: Transaction is Normal.
# Transaction 500: Transaction is Normal.
# Transaction 501: Transaction is Normal.
# Transaction 502: Transaction is Normal.
# Transaction 503: Transaction is Normal.
# Transaction 504: Transaction is Normal.
# Transaction 505: Transaction is Normal.
# Transaction 506: Transaction is Normal.
# Transaction 507: Transaction is Normal.
# Transaction 508: Transaction is Normal.
# Transaction 509: Transaction is Normal.
# Transaction 510: Transaction is Normal.
# Transaction 511: Transaction is Normal.
# Transaction 512: Transaction is Normal.
# Transaction 513: Transaction is Normal.
# Transaction 514: Transaction is Normal.
# Transaction 515: Transaction is Normal.
# Transaction 516: Transaction is Normal.
# Transaction 517: Transaction is Normal.
# Transaction 518: Transaction is Normal.
# Transaction 519: Transaction is Normal.
# Transaction 520: Transaction is Normal.
# Transaction 521: Transaction is Normal.
# Transaction 522: Transaction is Normal.
# Transaction 523: Transaction is Normal.
# Transaction 524: Transaction is Normal.
# Transaction 525: Transaction is Normal.
# Transaction 526: Transaction is Normal.
# Transaction 527: Transaction is Normal.
# Transaction 528: Transaction is Normal.
# Transaction 529: Transaction is Normal.
# Transaction 530: Transaction is Normal.
# Transaction 531: Transaction is Normal.
# Transaction 532: Transaction is Normal.
# Transaction 533: Transaction is Normal.
# Transaction 534: Transaction is Normal.
# Transaction 535: Transaction is Normal.
# Transaction 536: Transaction is Normal.
# Transaction 537: Transaction is Normal.
# Transaction 538: Transaction is Normal.
# Transaction 539: Transaction is Normal.
# Transaction 540: ALERT: Suspicious Transaction!
# Transaction 541: Transaction is Normal.
# Transaction 542: Transaction is Normal.
# Transaction 543: Transaction is Normal.
# Transaction 544: Transaction is Normal.
# Transaction 545: Transaction is Normal.
# Transaction 546: Transaction is Normal.
# Transaction 547: Transaction is Normal.
# Transaction 548: ALERT: Fraudulent Transaction!
# Transaction 549: Transaction is Normal.
# Transaction 550: Transaction is Normal.
# Transaction 551: Transaction is Normal.
# Transaction 552: Transaction is Normal.
# Transaction 553: Transaction is Normal.
# Transaction 554: Transaction is Normal.
# Transaction 555: Transaction is Normal.
# Transaction 556: Transaction is Normal.
# Transaction 557: Transaction is Normal.
# Transaction 558: Transaction is Normal.
# Transaction 559: Transaction is Normal.
# Transaction 560: Transaction is Normal.
# Transaction 561: Transaction is Normal.
# Transaction 562: Transaction is Normal.
# Transaction 563: Transaction is Normal.
# Transaction 564: Transaction is Normal.
# Transaction 565: Transaction is Normal.
# Transaction 566: Transaction is Normal.
# Transaction 567: Transaction is Normal.
# Transaction 568: Transaction is Normal.
# Transaction 569: Transaction is Normal.
# Transaction 570: Transaction is Normal.
# Transaction 571: Transaction is Normal.
# Transaction 572: Transaction is Normal.
# Transaction 573: Transaction is Normal.
# Transaction 574: Transaction is Normal.
# Transaction 575: Transaction is Normal.
# Transaction 576: Transaction is Normal.
# Transaction 577: Transaction is Normal.
# Transaction 578: Transaction is Normal.
# Transaction 579: Transaction is Normal.
# Transaction 580: Transaction is Normal.
# Transaction 581: Transaction is Normal.
# Transaction 582: Transaction is Normal.
# Transaction 583: Transaction is Normal.
# Transaction 584: Transaction is Normal.
# Transaction 585: Transaction is Normal.
# Transaction 586: Transaction is Normal.
# Transaction 587: Transaction is Normal.
# Transaction 588: Transaction is Normal.
# Transaction 589: Transaction is Normal.
# Transaction 590: Transaction is Normal.
# Transaction 591: Transaction is Normal.
# Transaction 592: Transaction is Normal.
# Transaction 593: Transaction is Normal.
# Transaction 594: Transaction is Normal.
# Transaction 595: Transaction is Normal.
# Transaction 596: Transaction is Normal.
# Transaction 597: Transaction is Normal.
# Transaction 598: Transaction is Normal.
# Transaction 599: Transaction is Normal.
# Transaction 600: Transaction is Normal.
# Transaction 601: Transaction is Normal.
# Transaction 602: Transaction is Normal.
# Transaction 603: Transaction is Normal.
# Transaction 604: Transaction is Normal.
# Transaction 605: Transaction is Normal.
# Transaction 606: Transaction is Normal.
# Transaction 607: Transaction is Normal.
# Transaction 608: Transaction is Normal.
# Transaction 609: Transaction is Normal.
# Transaction 610: Transaction is Normal.
# Transaction 611: Transaction is Normal.
# Transaction 612: Transaction is Normal.
# Transaction 613: Transaction is Normal.
# Transaction 614: Transaction is Normal.
# Transaction 615: Transaction is Normal.
# Transaction 616: Transaction is Normal.
# Transaction 617: Transaction is Normal.
# Transaction 618: Transaction is Normal.
# Transaction 619: Transaction is Normal.
# Transaction 620: Transaction is Normal.
# Transaction 621: Transaction is Normal.
# Transaction 622: Transaction is Normal.
# Transaction 623: Transaction is Normal.
# Transaction 624: Transaction is Normal.
# Transaction 625: Transaction is Normal.
# Transaction 626: Transaction is Normal.
# Transaction 627: Transaction is Normal.
# Transaction 628: Transaction is Normal.
# Transaction 629: Transaction is Normal.
# Transaction 630: Transaction is Normal.
# Transaction 631: Transaction is Normal.
# Transaction 632: Transaction is Normal.
# Transaction 633: Transaction is Normal.
# Transaction 634: Transaction is Normal.
# Transaction 635: Transaction is Normal.
# Transaction 636: Transaction is Normal.
# Transaction 637: Transaction is Normal.
# Transaction 638: Transaction is Normal.
# Transaction 639: Transaction is Normal.
# Transaction 640: Transaction is Normal.
# Transaction 641: Transaction is Normal.
# Transaction 642: Transaction is Normal.
# Transaction 643: Transaction is Normal.
# Transaction 644: Transaction is Normal.
# Transaction 645: Transaction is Normal.
# Transaction 646: Transaction is Normal.
# Transaction 647: Transaction is Normal.
# Transaction 648: Transaction is Normal.
# Transaction 649: Transaction is Normal.
# Transaction 650: Transaction is Normal.
# Transaction 651: Transaction is Normal.
# Transaction 652: Transaction is Normal.
# Transaction 653: Transaction is Normal.
# Transaction 654: Transaction is Normal.
# Transaction 655: Transaction is Normal.
# Transaction 656: Transaction is Normal.
# Transaction 657: Transaction is Normal.
# Transaction 658: Transaction is Normal.
# Transaction 659: Transaction is Normal.
# Transaction 660: Transaction is Normal.
# Transaction 661: Transaction is Normal.
# Transaction 662: Transaction is Normal.
# Transaction 663: Transaction is Normal.
# Transaction 664: Transaction is Normal.
# Transaction 665: Transaction is Normal.
# Transaction 666: Transaction is Normal.
# Transaction 667: Transaction is Normal.
# Transaction 668: Transaction is Normal.
# Transaction 669: Transaction is Normal.
# Transaction 670: Transaction is Normal.
# Transaction 671: Transaction is Normal.
# Transaction 672: Transaction is Normal.
# Transaction 673: Transaction is Normal.
# Transaction 674: Transaction is Normal.
# Transaction 675: Transaction is Normal.
# Transaction 676: Transaction is Normal.
# Transaction 677: Transaction is Normal.
# Transaction 678: Transaction is Normal.
# Transaction 679: Transaction is Normal.
# Transaction 680: Transaction is Normal.
# Transaction 681: Transaction is Normal.
# Transaction 682: Transaction is Normal.
# Transaction 683: Transaction is Normal.
# Transaction 684: Transaction is Normal.
# Transaction 685: Transaction is Normal.
# Transaction 686: Transaction is Normal.
# Transaction 687: Transaction is Normal.
# Transaction 688: Transaction is Normal.
# Transaction 689: Transaction is Normal.
# Transaction 690: Transaction is Normal.
# Transaction 691: Transaction is Normal.
# Transaction 692: Transaction is Normal.
# Transaction 693: Transaction is Normal.
# Transaction 694: Transaction is Normal.
# Transaction 695: Transaction is Normal.
# Transaction 696: Transaction is Normal.
# Transaction 697: Transaction is Normal.
# Transaction 698: Transaction is Normal.
# Transaction 699: Transaction is Normal.
# Transaction 700: Transaction is Normal.
# Transaction 701: Transaction is Normal.
# Transaction 702: ALERT: Suspicious Transaction!
# Transaction 703: Transaction is Normal.
# Transaction 704: Transaction is Normal.
# Transaction 705: Transaction is Normal.
# Transaction 706: Transaction is Normal.
# Transaction 707: Transaction is Normal.
# Transaction 708: Transaction is Normal.
# Transaction 709: Transaction is Normal.
# Transaction 710: Transaction is Normal.
# Transaction 711: Transaction is Normal.
# Transaction 712: Transaction is Normal.
# Transaction 713: Transaction is Normal.
# Transaction 714: Transaction is Normal.
# Transaction 715: Transaction is Normal.
# Transaction 716: Transaction is Normal.
# Transaction 717: Transaction is Normal.
# Transaction 718: Transaction is Normal.
# Transaction 719: Transaction is Normal.
# Transaction 720: Transaction is Normal.
# Transaction 721: Transaction is Normal.
# Transaction 722: Transaction is Normal.
# Transaction 723: Transaction is Normal.
# Transaction 724: Transaction is Normal.
# Transaction 725: Transaction is Normal.
# Transaction 726: Transaction is Normal.
# Transaction 727: Transaction is Normal.
# Transaction 728: Transaction is Normal.
# Transaction 729: Transaction is Normal.
# Transaction 730: Transaction is Normal.
# Transaction 731: Transaction is Normal.
# Transaction 732: Transaction is Normal.
# Transaction 733: Transaction is Normal.
# Transaction 734: Transaction is Normal.
# Transaction 735: Transaction is Normal.
# Transaction 736: Transaction is Normal.
# Transaction 737: Transaction is Normal.
# Transaction 738: Transaction is Normal.
# Transaction 739: Transaction is Normal.
# Transaction 740: Transaction is Normal.
# Transaction 741: Transaction is Normal.
# Transaction 742: Transaction is Normal.
# Transaction 743: Transaction is Normal.
# Transaction 744: Transaction is Normal.
# Transaction 745: Transaction is Normal.
# Transaction 746: Transaction is Normal.
# Transaction 747: Transaction is Normal.
# Transaction 748: Transaction is Normal.
# Transaction 749: Transaction is Normal.
# Transaction 750: Transaction is Normal.
# Transaction 751: Transaction is Normal.
# Transaction 752: Transaction is Normal.
# Transaction 753: Transaction is Normal.
# Transaction 754: Transaction is Normal.
# Transaction 755: Transaction is Normal.
# Transaction 756: Transaction is Normal.
# Transaction 757: Transaction is Normal.
# Transaction 758: Transaction is Normal.
# Transaction 759: Transaction is Normal.
# Transaction 760: Transaction is Normal.
# Transaction 761: Transaction is Normal.
# Transaction 762: Transaction is Normal.
# Transaction 763: Transaction is Normal.
# Transaction 764: Transaction is Normal.
# Transaction 765: Transaction is Normal.
# Transaction 766: Transaction is Normal.
# Transaction 767: Transaction is Normal.
# Transaction 768: Transaction is Normal.
# Transaction 769: Transaction is Normal.
# Transaction 770: Transaction is Normal.
# Transaction 771: Transaction is Normal.
# Transaction 772: Transaction is Normal.
# Transaction 773: Transaction is Normal.
# Transaction 774: Transaction is Normal.
# Transaction 775: Transaction is Normal.
# Transaction 776: Transaction is Normal.
# Transaction 777: Transaction is Normal.
# Transaction 778: Transaction is Normal.
# Transaction 779: Transaction is Normal.
# Transaction 780: Transaction is Normal.
# Transaction 781: Transaction is Normal.
# Transaction 782: Transaction is Normal.
# Transaction 783: Transaction is Normal.
# Transaction 784: Transaction is Normal.
# Transaction 785: Transaction is Normal.
# Transaction 786: Transaction is Normal.
# Transaction 787: Transaction is Normal.
# Transaction 788: Transaction is Normal.
# Transaction 789: Transaction is Normal.
# Transaction 790: Transaction is Normal.
# Transaction 791: Transaction is Normal.
# Transaction 792: Transaction is Normal.
# Transaction 793: Transaction is Normal.
# Transaction 794: Transaction is Normal.
# Transaction 795: Transaction is Normal.
# Transaction 796: Transaction is Normal.
# Transaction 797: Transaction is Normal.
# Transaction 798: Transaction is Normal.
# Transaction 799: Transaction is Normal.
# Transaction 800: Transaction is Normal.
# Transaction 801: Transaction is Normal.
# Transaction 802: Transaction is Normal.
# Transaction 803: Transaction is Normal.
# Transaction 804: Transaction is Normal.
# Transaction 805: Transaction is Normal.
# Transaction 806: Transaction is Normal.
# Transaction 807: Transaction is Normal.
# Transaction 808: Transaction is Normal.
# Transaction 809: Transaction is Normal.
# Transaction 810: Transaction is Normal.
# Transaction 811: Transaction is Normal.
# Transaction 812: Transaction is Normal.
# Transaction 813: Transaction is Normal.
# Transaction 814: Transaction is Normal.
# Transaction 815: Transaction is Normal.
# Transaction 816: Transaction is Normal.
# Transaction 817: Transaction is Normal.
# Transaction 818: Transaction is Normal.
# Transaction 819: Transaction is Normal.
# Transaction 820: Transaction is Normal.
# Transaction 821: Transaction is Normal.
# Transaction 822: Transaction is Normal.
# Transaction 823: Transaction is Normal.
# Transaction 824: Transaction is Normal.
# Transaction 825: Transaction is Normal.
# Transaction 826: Transaction is Normal.
# Transaction 827: Transaction is Normal.
# Transaction 828: Transaction is Normal.
# Transaction 829: Transaction is Normal.
# Transaction 830: Transaction is Normal.
# Transaction 831: Transaction is Normal.
# Transaction 832: Transaction is Normal.
# Transaction 833: Transaction is Normal.
# Transaction 834: Transaction is Normal.
# Transaction 835: Transaction is Normal.
# Transaction 836: Transaction is Normal.
# Transaction 837: Transaction is Normal.
# Transaction 838: Transaction is Normal.
# Transaction 839: Transaction is Normal.
# Transaction 840: Transaction is Normal.
# Transaction 841: Transaction is Normal.
# Transaction 842: Transaction is Normal.
# Transaction 843: Transaction is Normal.
# Transaction 844: Transaction is Normal.
# Transaction 845: Transaction is Normal.
# Transaction 846: Transaction is Normal.
# Transaction 847: Transaction is Normal.
# Transaction 848: Transaction is Normal.
# Transaction 849: Transaction is Normal.
# Transaction 850: Transaction is Normal.
# Transaction 851: Transaction is Normal.
# Transaction 852: Transaction is Normal.
# Transaction 853: Transaction is Normal.
# Transaction 854: Transaction is Normal.
# Transaction 855: Transaction is Normal.
# Transaction 856: Transaction is Normal.
# Transaction 857: Transaction is Normal.
# Transaction 858: Transaction is Normal.
# Transaction 859: Transaction is Normal.
# Transaction 860: Transaction is Normal.
# Transaction 861: Transaction is Normal.
# Transaction 862: Transaction is Normal.
# Transaction 863: Transaction is Normal.
# Transaction 864: Transaction is Normal.
# Transaction 865: Transaction is Normal.
# Transaction 866: Transaction is Normal.
# Transaction 867: Transaction is Normal.
# Transaction 868: Transaction is Normal.
# Transaction 869: Transaction is Normal.
# Transaction 870: Transaction is Normal.
# Transaction 871: Transaction is Normal.
# Transaction 872: Transaction is Normal.
# Transaction 873: Transaction is Normal.
# Transaction 874: Transaction is Normal.
# Transaction 875: Transaction is Normal.
# Transaction 876: Transaction is Normal.
# Transaction 877: Transaction is Normal.
# Transaction 878: Transaction is Normal.
# Transaction 879: Transaction is Normal.
# Transaction 880: Transaction is Normal.
# Transaction 881: Transaction is Normal.
# Transaction 882: Transaction is Normal.
# Transaction 883: Transaction is Normal.
# Transaction 884: Transaction is Normal.
# Transaction 885: Transaction is Normal.
# Transaction 886: ALERT: Suspicious Transaction!
# Transaction 887: Transaction is Normal.
# Transaction 888: Transaction is Normal.
# Transaction 889: Transaction is Normal.
# Transaction 890: Transaction is Normal.
# Transaction 891: Transaction is Normal.
# Transaction 892: Transaction is Normal.
# Transaction 893: Transaction is Normal.
# Transaction 894: Transaction is Normal.
# Transaction 895: Transaction is Normal.
# Transaction 896: Transaction is Normal.
# Transaction 897: Transaction is Normal.
# Transaction 898: Transaction is Normal.
# Transaction 899: Transaction is Normal.
# Transaction 900: Transaction is Normal.
# Transaction 901: Transaction is Normal.
# Transaction 902: Transaction is Normal.
# Transaction 903: Transaction is Normal.
# Transaction 904: Transaction is Normal.
# Transaction 905: Transaction is Normal.
# Transaction 906: Transaction is Normal.
# Transaction 907: Transaction is Normal.
# Transaction 908: Transaction is Normal.
# Transaction 909: Transaction is Normal.
# Transaction 910: Transaction is Normal.
# Transaction 911: Transaction is Normal.
# Transaction 912: Transaction is Normal.
# Transaction 913: Transaction is Normal.
# Transaction 914: Transaction is Normal.
# Transaction 915: Transaction is Normal.
# Transaction 916: Transaction is Normal.
# Transaction 917: Transaction is Normal.
# Transaction 918: Transaction is Normal.
# Transaction 919: Transaction is Normal.
# Transaction 920: Transaction is Normal.
# Transaction 921: Transaction is Normal.
# Transaction 922: Transaction is Normal.
# Transaction 923: Transaction is Normal.
# Transaction 924: Transaction is Normal.
# Transaction 925: Transaction is Normal.
# Transaction 926: Transaction is Normal.
# Transaction 927: Transaction is Normal.
# Transaction 928: Transaction is Normal.
# Transaction 929: Transaction is Normal.
# Transaction 930: Transaction is Normal.
# Transaction 931: Transaction is Normal.
# Transaction 932: Transaction is Normal.
# Transaction 933: Transaction is Normal.
# Transaction 934: Transaction is Normal.
# Transaction 935: Transaction is Normal.
# Transaction 936: Transaction is Normal.
# Transaction 937: Transaction is Normal.
# Transaction 938: Transaction is Normal.
# Transaction 939: Transaction is Normal.
# Transaction 940: Transaction is Normal.
# Transaction 941: Transaction is Normal.
# Transaction 942: Transaction is Normal.
# Transaction 943: Transaction is Normal.
# Transaction 944: Transaction is Normal.
# Transaction 945: Transaction is Normal.
# Transaction 946: Transaction is Normal.
# Transaction 947: Transaction is Normal.
# Transaction 948: Transaction is Normal.
# Transaction 949: Transaction is Normal.
# Transaction 950: Transaction is Normal.
# Transaction 951: Transaction is Normal.
# Transaction 952: ALERT: Fraudulent Transaction!
# Transaction 953: Transaction is Normal.
# Transaction 954: Transaction is Normal.
# Transaction 955: Transaction is Normal.
# Transaction 956: Transaction is Normal.
# Transaction 957: Transaction is Normal.
# Transaction 958: Transaction is Normal.
# Transaction 959: Transaction is Normal.
# Transaction 960: Transaction is Normal.
# Transaction 961: Transaction is Normal.
# Transaction 962: Transaction is Normal.
# Transaction 963: Transaction is Normal.
# Transaction 964: Transaction is Normal.
# Transaction 965: Transaction is Normal.
# Transaction 966: Transaction is Normal.
# Transaction 967: Transaction is Normal.
# Transaction 968: Transaction is Normal.
# Transaction 969: Transaction is Normal.
# Transaction 970: Transaction is Normal.
# Transaction 971: Transaction is Normal.
# Transaction 972: Transaction is Normal.
# Transaction 973: Transaction is Normal.
# Transaction 974: Transaction is Normal.
# Transaction 975: Transaction is Normal.
# Transaction 976: Transaction is Normal.
# Transaction 977: Transaction is Normal.
# Transaction 978: Transaction is Normal.
# Transaction 979: Transaction is Normal.
# Transaction 980: Transaction is Normal.
# Transaction 981: Transaction is Normal.
# Transaction 982: Transaction is Normal.
# Transaction 983: Transaction is Normal.
# Transaction 984: Transaction is Normal.
# Transaction 985: Transaction is Normal.
# Transaction 986: Transaction is Normal.
# Transaction 987: Transaction is Normal.
# Transaction 988: Transaction is Normal.
# Transaction 989: Transaction is Normal.
# Transaction 990: Transaction is Normal.
# Transaction 991: Transaction is Normal.
# Transaction 992: Transaction is Normal.
# Transaction 993: Transaction is Normal.
# Transaction 994: Transaction is Normal.
# Transaction 995: Transaction is Normal.
# Transaction 996: Transaction is Normal.
# Transaction 997: Transaction is Normal.
# Transaction 998: Transaction is Normal.
# Transaction 999: Transaction is Normal.
# Transaction 1000: Transaction is Normal.
# Transaction 1001: Transaction is Normal.
# Transaction 1002: Transaction is Normal.
# Transaction 1003: Transaction is Normal.
# Transaction 1004: Transaction is Normal.
# Transaction 1005: Transaction is Normal.
# Transaction 1006: Transaction is Normal.
# Transaction 1007: Transaction is Normal.
# Transaction 1008: Transaction is Normal.
# Transaction 1009: Transaction is Normal.
# Transaction 1010: Transaction is Normal.
# Transaction 1011: Transaction is Normal.
# Transaction 1012: Transaction is Normal.
# Transaction 1013: Transaction is Normal.
# Transaction 1014: Transaction is Normal.
# Transaction 1015: Transaction is Normal.
# Transaction 1016: Transaction is Normal.
# Transaction 1017: Transaction is Normal.
# Transaction 1018: Transaction is Normal.
# Transaction 1019: Transaction is Normal.
# Transaction 1020: Transaction is Normal.
# Transaction 1021: Transaction is Normal.
# Transaction 1022: Transaction is Normal.
# Transaction 1023: Transaction is Normal.
# Transaction 1024: Transaction is Normal.
# Transaction 1025: Transaction is Normal.
# Transaction 1026: Transaction is Normal.
# Transaction 1027: Transaction is Normal.
# Transaction 1028: Transaction is Normal.
# Transaction 1029: Transaction is Normal.
# Transaction 1030: Transaction is Normal.
# Transaction 1031: Transaction is Normal.
# Transaction 1032: Transaction is Normal.
# Transaction 1033: Transaction is Normal.
# Transaction 1034: Transaction is Normal.
# Transaction 1035: Transaction is Normal.
# Transaction 1036: Transaction is Normal.
# Transaction 1037: Transaction is Normal.
# Transaction 1038: Transaction is Normal.
# Transaction 1039: Transaction is Normal.
# Transaction 1040: Transaction is Normal.
# Transaction 1041: Transaction is Normal.
# Transaction 1042: Transaction is Normal.
# Transaction 1043: Transaction is Normal.
# Transaction 1044: Transaction is Normal.
# Transaction 1045: Transaction is Normal.
# Transaction 1046: Transaction is Normal.
# Transaction 1047: Transaction is Normal.
# Transaction 1048: Transaction is Normal.
# Transaction 1049: Transaction is Normal.
# Transaction 1050: Transaction is Normal.
# Transaction 1051: Transaction is Normal.
# Transaction 1052: Transaction is Normal.
# Transaction 1053: Transaction is Normal.
# Transaction 1054: Transaction is Normal.
# Transaction 1055: Transaction is Normal.
# Transaction 1056: Transaction is Normal.
# Transaction 1057: Transaction is Normal.
# Transaction 1058: Transaction is Normal.
# Transaction 1059: ALERT: Suspicious Transaction!
# Transaction 1060: Transaction is Normal.
# Transaction 1061: Transaction is Normal.
# Transaction 1062: Transaction is Normal.
# Transaction 1063: Transaction is Normal.
# Transaction 1064: Transaction is Normal.
# Transaction 1065: Transaction is Normal.
# Transaction 1066: Transaction is Normal.
# Transaction 1067: Transaction is Normal.
# Transaction 1068: Transaction is Normal.
# Transaction 1069: Transaction is Normal.
# Transaction 1070: Transaction is Normal.
# Transaction 1071: Transaction is Normal.
# Transaction 1072: Transaction is Normal.
# Transaction 1073: Transaction is Normal.
# Transaction 1074: Transaction is Normal.
# Transaction 1075: Transaction is Normal.
# Transaction 1076: Transaction is Normal.
# Transaction 1077: Transaction is Normal.
# Transaction 1078: Transaction is Normal.
# Transaction 1079: Transaction is Normal.
# Transaction 1080: Transaction is Normal.
# Transaction 1081: Transaction is Normal.
# Transaction 1082: Transaction is Normal.
# Transaction 1083: Transaction is Normal.
# Transaction 1084: Transaction is Normal.
# Transaction 1085: Transaction is Normal.
# Transaction 1086: Transaction is Normal.
# Transaction 1087: Transaction is Normal.
# Transaction 1088: Transaction is Normal.
# Transaction 1089: Transaction is Normal.
# Transaction 1090: Transaction is Normal.
# Transaction 1091: ALERT: Suspicious Transaction!
# Transaction 1092: Transaction is Normal.
# Transaction 1093: Transaction is Normal.
# Transaction 1094: Transaction is Normal.
# Transaction 1095: Transaction is Normal.
# Transaction 1096: Transaction is Normal.
# Transaction 1097: Transaction is Normal.
# Transaction 1098: Transaction is Normal.
# Transaction 1099: Transaction is Normal.
# Transaction 1100: Transaction is Normal.
# Transaction 1101: Transaction is Normal.
# Transaction 1102: Transaction is Normal.
# Transaction 1103: Transaction is Normal.
# Transaction 1104: Transaction is Normal.
# Transaction 1105: Transaction is Normal.
# Transaction 1106: Transaction is Normal.
# Transaction 1107: Transaction is Normal.
# Transaction 1108: Transaction is Normal.
# Transaction 1109: Transaction is Normal.
# Transaction 1110: Transaction is Normal.
# Transaction 1111: Transaction is Normal.
# Transaction 1112: Transaction is Normal.
# Transaction 1113: Transaction is Normal.
# Transaction 1114: Transaction is Normal.
# Transaction 1115: Transaction is Normal.
# Transaction 1116: Transaction is Normal.
# Transaction 1117: Transaction is Normal.
# Transaction 1118: Transaction is Normal.
# Transaction 1119: Transaction is Normal.
# Transaction 1120: Transaction is Normal.
# Transaction 1121: Transaction is Normal.
# Transaction 1122: Transaction is Normal.
# Transaction 1123: Transaction is Normal.
# Transaction 1124: Transaction is Normal.
# Transaction 1125: Transaction is Normal.
# Transaction 1126: Transaction is Normal.
# Transaction 1127: Transaction is Normal.
# Transaction 1128: Transaction is Normal.
# Transaction 1129: Transaction is Normal.
# Transaction 1130: Transaction is Normal.
# Transaction 1131: Transaction is Normal.
# Transaction 1132: Transaction is Normal.
# Transaction 1133: Transaction is Normal.
# Transaction 1134: Transaction is Normal.
# Transaction 1135: Transaction is Normal.
# Transaction 1136: Transaction is Normal.
# Transaction 1137: Transaction is Normal.
# Transaction 1138: Transaction is Normal.
# Transaction 1139: Transaction is Normal.
# Transaction 1140: Transaction is Normal.
# Transaction 1141: Transaction is Normal.
# Transaction 1142: ALERT: Suspicious Transaction!
# Transaction 1143: Transaction is Normal.
# Transaction 1144: Transaction is Normal.
# Transaction 1145: Transaction is Normal.
# Transaction 1146: Transaction is Normal.
# Transaction 1147: Transaction is Normal.
# Transaction 1148: Transaction is Normal.
# Transaction 1149: Transaction is Normal.
# Transaction 1150: Transaction is Normal.
# Transaction 1151: Transaction is Normal.
# Transaction 1152: Transaction is Normal.
# Transaction 1153: Transaction is Normal.
# Transaction 1154: Transaction is Normal.
# Transaction 1155: Transaction is Normal.
# Transaction 1156: Transaction is Normal.
# Transaction 1157: Transaction is Normal.
# Transaction 1158: Transaction is Normal.
# Transaction 1159: Transaction is Normal.
# Transaction 1160: Transaction is Normal.
# Transaction 1161: Transaction is Normal.
# Transaction 1162: Transaction is Normal.
# Transaction 1163: Transaction is Normal.
# Transaction 1164: Transaction is Normal.
# Transaction 1165: Transaction is Normal.
# Transaction 1166: Transaction is Normal.
# Transaction 1167: Transaction is Normal.
# Transaction 1168: Transaction is Normal.
# Transaction 1169: Transaction is Normal.
# Transaction 1170: Transaction is Normal.
# Transaction 1171: Transaction is Normal.
# Transaction 1172: Transaction is Normal.
# Transaction 1173: Transaction is Normal.
# Transaction 1174: Transaction is Normal.
# Transaction 1175: Transaction is Normal.
# Transaction 1176: Transaction is Normal.
# Transaction 1177: Transaction is Normal.
# Transaction 1178: Transaction is Normal.
# Transaction 1179: Transaction is Normal.
# Transaction 1180: Transaction is Normal.
# Transaction 1181: Transaction is Normal.
# Transaction 1182: Transaction is Normal.
# Transaction 1183: Transaction is Normal.
# Transaction 1184: Transaction is Normal.
# Transaction 1185: Transaction is Normal.
# Transaction 1186: Transaction is Normal.
# Transaction 1187: Transaction is Normal.
# Transaction 1188: Transaction is Normal.
# Transaction 1189: Transaction is Normal.
# Transaction 1190: Transaction is Normal.
# Transaction 1191: Transaction is Normal.
# Transaction 1192: Transaction is Normal.
# Transaction 1193: Transaction is Normal.
# Transaction 1194: Transaction is Normal.
# ...
# Transaction 31371: Transaction is Normal.
# Transaction 31372: Transaction is Normal.
# Transaction 31373: Transaction is Normal.
# Transaction 31374: Transaction is Normal.
# Transaction 31375: Transaction is Normal.
# Transaction 31376: Transaction is Normal.
# Transaction 31377: Transaction is Normal.
# Transaction 31378: Transaction is Normal.
# Transaction 31379: Transaction is Normal.
# Transaction 31380: Transaction is Normal.
# Transaction 31381: Transaction is Normal.
# Transaction 31382: Transaction is Normal.
# Transaction 31383: Transaction is Normal.
# Transaction 31384: Transaction is Normal.
# Transaction 31385: Transaction is Normal.
# Transaction 31386: Transaction is Normal.
# Transaction 31387: Transaction is Normal.
# Transaction 31388: Transaction is Normal.
# Transaction 31389: Transaction is Normal.
# Transaction 31390: Transaction is Normal.
# Transaction 31391: Transaction is Normal.
# Transaction 31392: Transaction is Normal.
# Transaction 31393: Transaction is Normal.
# Transaction 31394: Transaction is Normal.
# Transaction 31395: Transaction is Normal.
# Transaction 31396: Transaction is Normal.
# Transaction 31397: Transaction is Normal.
# Transaction 31398: Transaction is Normal.
# Transaction 31399: Transaction is Normal.
# Transaction 31400: Transaction is Normal.
# Transaction 31401: Transaction is Normal.
# Transaction 31402: Transaction is Normal.
# Transaction 31403: Transaction is Normal.
# Transaction 31404: Transaction is Normal.
# Transaction 31405: Transaction is Normal.
# Transaction 31406: Transaction is Normal.
# Transaction 31407: Transaction is Normal.
# Transaction 31408: Transaction is Normal.
# Transaction 31409: Transaction is Normal.
# Transaction 31410: Transaction is Normal.
# Transaction 31411: Transaction is Normal.
# Transaction 31412: Transaction is Normal.
# Transaction 31413: Transaction is Normal.
# Transaction 31414: Transaction is Normal.
# Transaction 31415: Transaction is Normal.
# Transaction 31416: Transaction is Normal.
# Transaction 31417: Transaction is Normal.
# Transaction 31418: Transaction is Normal.
# Transaction 31419: Transaction is Normal.
# Transaction 31420: Transaction is Normal.
# Transaction 31421: Transaction is Normal.
# Transaction 31422: Transaction is Normal.
# Transaction 31423: Transaction is Normal.
# Transaction 31424: Transaction is Normal.
# Transaction 31425: Transaction is Normal.
# Transaction 31426: Transaction is Normal.
# Transaction 31427: Transaction is Normal.
# Transaction 31428: Transaction is Normal.
# Transaction 31429: Transaction is Normal.
# Transaction 31430: Transaction is Normal.
# Transaction 31431: Transaction is Normal.
# Transaction 31432: Transaction is Normal.
# Transaction 31433: Transaction is Normal.
# Transaction 31434: Transaction is Normal.
# Transaction 31435: Transaction is Normal.
# Transaction 31436: Transaction is Normal.
# Transaction 31437: Transaction is Normal.
# Transaction 31438: Transaction is Normal.
# Transaction 31439: Transaction is Normal.
# Transaction 31440: Transaction is Normal.
# Transaction 31441: Transaction is Normal.
# Transaction 31442: Transaction is Normal.
# Transaction 31443: Transaction is Normal.
# Transaction 31444: Transaction is Normal.
# Transaction 31445: Transaction is Normal.
# Transaction 31446: Transaction is Normal.
# Transaction 31447: Transaction is Normal.
# Transaction 31448: Transaction is Normal.
# Transaction 31449: Transaction is Normal.
# Transaction 31450: Transaction is Normal.
# Transaction 31451: Transaction is Normal.
# Transaction 31452: Transaction is Normal.
# Transaction 31453: Transaction is Normal.
# Transaction 31454: Transaction is Normal.
# Transaction 31455: Transaction is Normal.
# Transaction 31456: Transaction is Normal.
# Transaction 31457: Transaction is Normal.
# Transaction 31458: Transaction is Normal.
# Transaction 31459: Transaction is Normal.
# Transaction 31460: Transaction is Normal.
# Transaction 31461: Transaction is Normal.
# Transaction 31462: Transaction is Normal.
# Transaction 31463: Transaction is Normal.
# Transaction 31464: Transaction is Normal.
# Transaction 31465: Transaction is Normal.
# Transaction 31466: Transaction is Normal.
# Transaction 31467: Transaction is Normal.
# Transaction 31468: Transaction is Normal.
# Transaction 31469: Transaction is Normal.
# Transaction 31470: Transaction is Normal.
# Transaction 31471: Transaction is Normal.
# Transaction 31472: Transaction is Normal.
# Transaction 31473: Transaction is Normal.
# Transaction 31474: Transaction is Normal.
# Transaction 31475: Transaction is Normal.
# Transaction 31476: Transaction is Normal.
# Transaction 31477: Transaction is Normal.
# Transaction 31478: Transaction is Normal.
# Transaction 31479: Transaction is Normal.
# Transaction 31480: Transaction is Normal.
# Transaction 31481: Transaction is Normal.
# Transaction 31482: Transaction is Normal.
# Transaction 31483: Transaction is Normal.
# Transaction 31484: Transaction is Normal.
# Transaction 31485: Transaction is Normal.
# Transaction 31486: Transaction is Normal.
# Transaction 31487: Transaction is Normal.
# Transaction 31488: Transaction is Normal.
# Transaction 31489: Transaction is Normal.
# Transaction 31490: Transaction is Normal.
# Transaction 31491: Transaction is Normal.
# Transaction 31492: Transaction is Normal.
# Transaction 31493: Transaction is Normal.
# Transaction 31494: ALERT: Suspicious Transaction!
# Transaction 31495: Transaction is Normal.
# Transaction 31496: Transaction is Normal.
# Transaction 31497: Transaction is Normal.
# Transaction 31498: Transaction is Normal.
# Transaction 31499: Transaction is Normal.
# Transaction 31500: Transaction is Normal.
# Transaction 31501: Transaction is Normal.
# Transaction 31502: Transaction is Normal.
# Transaction 31503: Transaction is Normal.
# Transaction 31504: Transaction is Normal.
# Transaction 31505: Transaction is Normal.
# Transaction 31506: Transaction is Normal.
# Transaction 31507: Transaction is Normal.
# Transaction 31508: ALERT: Suspicious Transaction!
# Transaction 31509: Transaction is Normal.
# Transaction 31510: Transaction is Normal.
# Transaction 31511: Transaction is Normal.
# Transaction 31512: Transaction is Normal.
# Transaction 31513: Transaction is Normal.
# Transaction 31514: Transaction is Normal.
# Transaction 31515: Transaction is Normal.
# Transaction 31516: Transaction is Normal.
# Transaction 31517: Transaction is Normal.
# Transaction 31518: Transaction is Normal.
# Transaction 31519: Transaction is Normal.
# Transaction 31520: Transaction is Normal.
# Transaction 31521: Transaction is Normal.
# Transaction 31522: Transaction is Normal.
# Transaction 31523: Transaction is Normal.
# Transaction 31524: Transaction is Normal.
# Transaction 31525: Transaction is Normal.
# Transaction 31526: Transaction is Normal.
# Transaction 31527: Transaction is Normal.
# Transaction 31528: Transaction is Normal.
# Transaction 31529: Transaction is Normal.
# Transaction 31530: Transaction is Normal.
# Transaction 31531: Transaction is Normal.
# Transaction 31532: Transaction is Normal.
# Transaction 31533: Transaction is Normal.
# Transaction 31534: Transaction is Normal.
# Transaction 31535: Transaction is Normal.
# Transaction 31536: Transaction is Normal.
# Transaction 31537: Transaction is Normal.
# Transaction 31538: Transaction is Normal.
# Transaction 31539: Transaction is Normal.
# Transaction 31540: Transaction is Normal.
# Transaction 31541: Transaction is Normal.
# Transaction 31542: Transaction is Normal.
# Transaction 31543: Transaction is Normal.
# Transaction 31544: Transaction is Normal.
# Transaction 31545: Transaction is Normal.
# Transaction 31546: Transaction is Normal.
# Transaction 31547: Transaction is Normal.
# Transaction 31548: Transaction is Normal.
# Transaction 31549: Transaction is Normal.
# Transaction 31550: Transaction is Normal.
# Transaction 31551: Transaction is Normal.
# Transaction 31552: Transaction is Normal.
# Transaction 31553: Transaction is Normal.
# Transaction 31554: Transaction is Normal.
# Transaction 31555: Transaction is Normal.
# Transaction 31556: Transaction is Normal.
# Transaction 31557: Transaction is Normal.
# Transaction 31558: Transaction is Normal.
# Transaction 31559: Transaction is Normal.
# Transaction 31560: Transaction is Normal.
# Transaction 31561: Transaction is Normal.
# Transaction 31562: Transaction is Normal.
# Transaction 31563: Transaction is Normal.
# Transaction 31564: Transaction is Normal.
# Transaction 31565: Transaction is Normal.
# Transaction 31566: Transaction is Normal.
# Transaction 31567: Transaction is Normal.
# Transaction 31568: Transaction is Normal.
# Transaction 31569: Transaction is Normal.
# Transaction 31570: Transaction is Normal.
# Transaction 31571: Transaction is Normal.
# Transaction 31572: Transaction is Normal.
# Transaction 31573: Transaction is Normal.
# Transaction 31574: Transaction is Normal.
# Transaction 31575: Transaction is Normal.
# Transaction 31576: Transaction is Normal.
# Transaction 31577: Transaction is Normal.
# Transaction 31578: Transaction is Normal.
# Transaction 31579: Transaction is Normal.
# Transaction 31580: Transaction is Normal.
# Transaction 31581: Transaction is Normal.
# Transaction 31582: Transaction is Normal.
# Transaction 31583: Transaction is Normal.
# Transaction 31584: Transaction is Normal.
# Transaction 31585: Transaction is Normal.
# Transaction 31586: Transaction is Normal.
# Transaction 31587: Transaction is Normal.
# Transaction 31588: Transaction is Normal.
# Transaction 31589: Transaction is Normal.
# Transaction 31590: Transaction is Normal.
# Transaction 31591: Transaction is Normal.
# Transaction 31592: Transaction is Normal.
# Transaction 31593: Transaction is Normal.
# Transaction 31594: Transaction is Normal.
# Transaction 31595: Transaction is Normal.
# Transaction 31596: Transaction is Normal.
# Transaction 31597: Transaction is Normal.
# Transaction 31598: Transaction is Normal.
# Transaction 31599: Transaction is Normal.
# Transaction 31600: Transaction is Normal.
# Transaction 31601: Transaction is Normal.
# Transaction 31602: Transaction is Normal.
# Transaction 31603: Transaction is Normal.
# Transaction 31604: Transaction is Normal.
# Transaction 31605: Transaction is Normal.
# Transaction 31606: Transaction is Normal.
# Transaction 31607: Transaction is Normal.
# Transaction 31608: Transaction is Normal.
# Transaction 31609: Transaction is Normal.
# Transaction 31610: Transaction is Normal.
# Transaction 31611: Transaction is Normal.
# Transaction 31612: Transaction is Normal.
# Transaction 31613: Transaction is Normal.
# Transaction 31614: Transaction is Normal.
# Transaction 31615: Transaction is Normal.
# Transaction 31616: Transaction is Normal.
# Transaction 31617: Transaction is Normal.
# Transaction 31618: Transaction is Normal.
# Transaction 31619: Transaction is Normal.
# Transaction 31620: Transaction is Normal.
# Transaction 31621: Transaction is Normal.
# Transaction 31622: Transaction is Normal.
# Transaction 31623: Transaction is Normal.
# Transaction 31624: Transaction is Normal.
# Transaction 31625: Transaction is Normal.
# Transaction 31626: Transaction is Normal.
# Transaction 31627: Transaction is Normal.
# Transaction 31628: Transaction is Normal.
# Transaction 31629: Transaction is Normal.
# Transaction 31630: Transaction is Normal.
# Transaction 31631: Transaction is Normal.
# Transaction 31632: Transaction is Normal.
# Transaction 31633: Transaction is Normal.
# Transaction 31634: Transaction is Normal.
# Transaction 31635: Transaction is Normal.
# Transaction 31636: Transaction is Normal.
# Transaction 31637: Transaction is Normal.
# Transaction 31638: Transaction is Normal.
# Transaction 31639: Transaction is Normal.
# Transaction 31640: Transaction is Normal.
# Transaction 31641: Transaction is Normal.
# Transaction 31642: Transaction is Normal.
# Transaction 31643: Transaction is Normal.
# Transaction 31644: Transaction is Normal.
# Transaction 31645: Transaction is Normal.
# Transaction 31646: Transaction is Normal.
# Transaction 31647: Transaction is Normal.
# Transaction 31648: Transaction is Normal.
# Transaction 31649: Transaction is Normal.
# Transaction 31650: Transaction is Normal.
# Transaction 31651: ALERT: Suspicious Transaction!
# Transaction 31652: Transaction is Normal.
# Transaction 31653: Transaction is Normal.
# Transaction 31654: Transaction is Normal.
# Transaction 31655: Transaction is Normal.
# Transaction 31656: Transaction is Normal.
# Transaction 31657: Transaction is Normal.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 9
#       4 for index in range(len(X_test)):
#       6     transaction = X_test.iloc[[index]]
# ----> 9     alert = alert_system(transaction)
#      10     print(f"Transaction {index}: {alert}")
#
# Cell In[12], line 3, in alert_system(transaction)
#       2 def alert_system(transaction):
# ----> 3     pred = model.predict(transaction)
#       4     if pred == 1:
#       5         return "ALERT: Fraudulent Transaction!"
#
# File C:\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File C:\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:957, in ForestClassifier.predict_proba(self, X)
#     952 all_proba = [
#     953     np.zeros((X.shape[0], j), dtype=np.float64)
#     954     for j in np.atleast_1d(self.n_classes_)
#     955 ]
#     956 lock = threading.Lock()
# --> 957 Parallel(n_jobs=n_jobs, verbose=self.verbose, require="sharedmem")(
#     958     delayed(_accumulate_prediction)(e.predict_proba, X, all_proba, lock)
#     959     for e in self.estimators_
#     960 )
#     962 for proba in all_proba:
#     963     proba /= len(self.estimators_)
#
# File C:\Python312\Lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File C:\Python312\Lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File C:\Python312\Lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File C:\Python312\Lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File C:\Python312\Lib\site-packages\sklearn\ensemble\_forest.py:731, in _accumulate_prediction(predict, X, out, lock)
#     724 def _accumulate_prediction(predict, X, out, lock):
#     725     """
#     726     This is a utility function for joblib's Parallel.
#     727
#     728     It can't go locally in ForestClassifier or ForestRegressor, because joblib
#     729     complains that it cannot pickle it when placed there.
#     730     """
# --> 731     prediction = predict(X, check_input=False)
#     732     with lock:
#     733         if len(out) == 1:
#
# File C:\Python312\Lib\site-packages\sklearn\tree\_classes.py:1043, in DecisionTreeClassifier.predict_proba(self, X, check_input)
#    1041 check_is_fitted(self)
#    1042 X = self._validate_X_predict(X, check_input)
# -> 1043 proba = self.tree_.predict(X)
#    1045 if self.n_outputs_ == 1:
#    1046     return proba[:, : self.n_classes_]
#
# KeyboardInterrupt:
